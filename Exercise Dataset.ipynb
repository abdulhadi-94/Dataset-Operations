# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("exercises.csv")

# %%
df.head()
# Out:
#                               id                        name_en  \
# 0                   arnold-press                   Arnold Press
# 1            banded-lateral-walk            Banded Lateral Walk
# 2           barbell-glute-bridge           Barbell Glute Bridge
# 3  behind-the-back-barbell-shrug  Behind the Back Barbell Shrug
# 4          behind-the-neck-press          Behind the Neck Press
#
#                               name_de  \
# 0                        Arnold Press
# 1               Lateral Walk mit Band
# 2              Langhantel-Gesäßbrücke
# 3  Langhantel-Shrug hinter dem Rücken
# 4                       Nackendrücken
#
#                                              name_es  category force_type  \
# 0                                       Press Arnold  strength       push
# 1                         Caminata Lateral con Banda  strength    dynamic
# 2                        Puente de Glúteos con Barra  strength       push
# ...

# %%
df.tail()
# Out:
#                              id                      name_en  \
# 16                     pec-deck                     Pec Deck
# 17                   push-press                   Push Press
# 18  smith-machine-bent-over-row  Smith Machine Bent Over Row
# 19          smith-machine-squat          Smith Machine Squat
# 20   wide-grip-seated-cable-row   Wide Grip Seated Cable Row
#
#                                      name_de  \
# 16                                  Pec Deck
# 17                                Push Press
# 18               Smith Machine Bent Over Row
# 19                  Smith-Maschine Kniebeuge
# 20  Sitzrudern mit breitem Griff am Kabelzug
#
#                                   name_es  category force_type   mechanic  \
# 16                               Pec Deck  strength       push  isolation
# 17                        Press de Empuje  strength       push   compound
# 18        Remo Inclinado en Máquina Smith  strength       pull   compound
# ...

# %%
df.shape
# Out:
# (21, 23)

# %%
df.columns
# Out:
# Index(['id', 'name_en', 'name_de', 'name_es', 'category', 'force_type',
#        'mechanic', 'difficulty', 'equipment', 'body_part', 'primary_muscles',
#        'secondary_muscles', 'goals', 'tags', 'met', 'is_unilateral',
#        'is_bodyweight', 'description_en', 'instructions_en',
#        'image_classic_start', 'image_classic_peak', 'image_flat_start',
#        'image_flat_peak'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   21 non-null     str
#  1   name_en              21 non-null     str
#  2   name_de              21 non-null     str
#  3   name_es              21 non-null     str
#  4   category             21 non-null     str
#  5   force_type           21 non-null     str
#  6   mechanic             21 non-null     str
#  7   difficulty           21 non-null     str
#  8   equipment            20 non-null     str
#  9   body_part            21 non-null     str
#  10  primary_muscles      21 non-null     str
#  11  secondary_muscles    20 non-null     str
#  12  goals                21 non-null     str
#  13  tags                 20 non-null     str
#  14  met                  21 non-null     float64
#  15  is_unilateral        21 non-null     bool
# ...

# %%
df.describe()
# Out:
#              met
# count  21.000000
# mean    5.714286
# std     0.462910
# min     5.000000
# 25%     5.000000
# 50%     6.000000
# 75%     6.000000
# max     6.000000

# %%
df.dtypes
# Out:
# id                         str
# name_en                    str
# name_de                    str
# name_es                    str
# category                   str
# force_type                 str
# mechanic                   str
# difficulty                 str
# equipment                  str
# body_part                  str
# primary_muscles            str
# secondary_muscles          str
# goals                      str
# tags                       str
# met                    float64
# is_unilateral             bool
# is_bodyweight             bool
# description_en             str
# instructions_en            str
# image_classic_start        str
# image_classic_peak         str
# image_flat_start           str
# image_flat_peak            str
# dtype: object

# %%
df.isnull().sum()
# Out:
# id                     0
# name_en                0
# name_de                0
# name_es                0
# category               0
# force_type             0
# mechanic               0
# difficulty             0
# equipment              1
# body_part              0
# primary_muscles        0
# secondary_muscles      1
# goals                  0
# tags                   1
# met                    0
# is_unilateral          0
# is_bodyweight          0
# description_en         0
# instructions_en        0
# image_classic_start    0
# image_classic_peak     0
# image_flat_start       0
# image_flat_peak        0
# dtype: int64

# %%
df.nunique()
# Out:
# id                     21
# name_en                21
# name_de                21
# name_es                21
# category                1
# force_type              3
# mechanic                2
# difficulty              2
# equipment               8
# body_part               7
# primary_muscles        13
# secondary_muscles      18
# goals                   4
# tags                   18
# met                     2
# is_unilateral           2
# is_bodyweight           2
# description_en         21
# instructions_en        21
# image_classic_start    21
# image_classic_peak     21
# image_flat_start       21
# image_flat_peak        21
# dtype: int64

# %%
df.sample(8)
# Out:
#                                id                        name_en  \
# 20     wide-grip-seated-cable-row     Wide Grip Seated Cable Row
# 10          double-kettlebell-row          Double Kettlebell Row
# 19            smith-machine-squat            Smith Machine Squat
# 1             banded-lateral-walk            Banded Lateral Walk
# 13      floor-kettlebell-pullover      Floor Kettlebell Pullover
# 9         cable-external-rotation        Cable External Rotation
# 3   behind-the-back-barbell-shrug  Behind the Back Barbell Shrug
# 5                      bench-dips                     Bench Dips
#
#                                      name_de  \
# 20  Sitzrudern mit breitem Griff am Kabelzug
# 10                  Double Kettlebell Rudern
# 19                  Smith-Maschine Kniebeuge
# 1                      Lateral Walk mit Band
# 13                 Boden Kettlebell Pullover
# 9                     Kabelzug Außenrotation
# 3         Langhantel-Shrug hinter dem Rücken
# ...

# %%
df.value_counts()
# Out:
# id                             name_en                        name_de                                   name_es                                                 category  force_type  mechanic   difficulty    equipment      body_part   primary_muscles                            secondary_muscles                                    goals                                 tags                                                                met  is_unilateral  is_bodyweight  description_en                                                                                                                                                                                                                             instructions_en                                                                                                                                                                                                                                                                                     
# ...
